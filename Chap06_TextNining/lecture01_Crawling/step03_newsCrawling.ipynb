# %%
'''
- news Crawling
  url : http://media.daum.net
'''

import requests
from bs4 import BeautifulSoup

url = "http://media.daum.net"

# 1. url 요청 
src = requests.get(url)
print(src) # <Response [200]>
# Out:
# <Response [200]>

# %%
html = src.text
# html 파싱 
soup = BeautifulSoup(html, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="os_unknown none unknown version_0 " lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="always" name="referrer">
# <meta content="Daum 뉴스" property="og:author"/>
# <meta content="다음뉴스" property="og:site_name"/>
# <meta content="홈" property="og:title"/>
# <meta content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" property="og:image"/>
# <meta content="다음뉴스" property="og:description"/>
# <meta content="https://news.daum.net/" property="og:url"/>
# <link href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico" rel="shortcut icon"/>
# <title>홈 | 다음뉴스</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="//t1.daumcdn.net/media/kraken/news/2cf5440/common.css.merged.css" rel="stylesheet" type="text/css">
# <link href="//t1.daumcdn.net/media/kraken/news/2cf5440/news.css.merged.css" rel="stylesheet" type="text/css"/>
# ...

# %%
# 2. tab[속성=값] 요소 추출 
atags = soup.select('a[class=link_txt]')
#print(atags)
print(len(atags))
# Out:
# 62

# %%
crawling_data = [] # 빈 list

cnt = 0 # 2차 작성 
for atag in atags :
    cnt += 1
    content = str(atag.string)
    print(cnt, '->', content)
    crawling_data.append(content.strip())
    '''
    string.strip() : 문단 끝 부분 공백, tab, \n\r 불용어 제거 
    '''
    
print('crawling result')    
print(crawling_data)
# Out:
# 1 -> 대검, 尹장모 모해위증 재수사 결정.. 장모측 "정치적 의도"
# 2 -> 대검, '장모 모해위증' 의혹 재수사 명령..이유는?
# 3 -> 대검, 尹장모 '모해위증'의혹 재수사 명령..尹측 "정치적 의도"
# 4 -> 또 '여성가족부 폐지' 꺼내든 유승민
# 5 -> 국민의힘 유승민·하태경 '여가부 폐지'..이대남 표심잡기
# 6 -> '이남자' 표심 그리 급했나..유승민·하태경 "여가부 폐지"
# 7 -> 양보 없는 최저임금 줄다리기..노사, 8일 1차 수정안 제시
# 8 -> 최저임금 양보 없는 줄다리기..공익위원의 시간 온다
# 9 -> "임금·복지 기준점 최저임금 올려야"VS"현행 최저임금도 버거워"
# 10 -> 야행성 장마에 500mm 물 폭탄..이젠 게릴라 장마
# 11 -> 경남·전북 호우특보..남부 내일까지 200mm 폭우
# 12 -> 밤부터 다시 폭우..남부 내일까지 200mm 물벼락
# 13 -> 尹장모 모해위증 의혹..대검 "다시 수사하라"
# 14 -> 이재명 '바지 발언' 맹공..이재명 "인터넷 찾아봐라"
# 15 -> '故 김홍영 검사 상습폭행' 부장검사..'징역 1년' 실형
# 16 -> 남해안에 최대 500mm 비..2명 사망·이재민 68명 등 190명 대피
# 17 -> 대한항공, 아시아나 임차 항공기에 色 입힌다..페인팅 계약
# 18 -> 한일 샅바싸움..靑, 文 '방일의사 전달' 日보도 일축
# 19 -> 현역장성 성추행 혐의 구속..서욱 "엄중하게 조치하라"
# 20 -> 델타 변이 확산 이후..이스라엘, 화이자 효과 60%로 '뚝'
# 21 -> 포항시장 만나 "후원 부탁"..소개한 기자 내사
# 22 -> 올림픽 앞둔 도쿄 코로나 상황 계속 악화..도로 성화봉송 취소
# 23 -> "美, 이란 제재 완화 등 징벌적 제재 사용 방식 개편" - WSJ
# 24 -> 中, 암호화폐 관련 기술 업체도 단속 경고..규제 강화
# 25 -> 미국은 지금
# 26 -> 전국 화재사고
# 27 -> 서울의 풍경
# ...

# %%
# text file save            
f = open('C:/Users/hyebin/Desktop/Python_ML/data/crawling_data.txt', mode='w', encoding='utf-8')

# %%
# list -> str 변환 
f.write(str(crawling_data))
f.close()    

print('crawling_data.txt 파일 확인 ')
# Out:
# crawling_data.txt 파일 확인
